# %%
from TRSF.main import trsf
import numpy as np 
import matplotlib.pyplot as plt
import os

PATH_Cosmo_r0p0 = '/Users/rs17612/Documents/Radio_Data/MIGHTEE/MIGHTEE_Continuum_Early_Science_COSMOS_r0p0.app.restored.circ.fits'
PATH_Cosmo_r0p0_corfac = '/Users/rs17612/Documents/Radio_Data/MIGHTEE/MIGHTEE_Continuum_Early_Science_COSMOS_r0p0_effective_frequency_pbcut_corrected.fits'

def file_exists(path):
    if os.path.isfile(path):
        print('File exists : '+path)
        #return True
    else:
        print('File does not exist : '+path)
        #return False
    
file_exists(PATH_Cosmo_r0p0)
# Out:
# File exists : /Users/rs17612/Documents/Radio_Data/MIGHTEE/MIGHTEE_Continuum_Early_Science_COSMOS_r0p0.app.restored.circ.fits

# %%
Cosmo_r0p0_data = trsf(PATH_Cosmo_r0p0,gaussian_fitting=True,region_expansion=False,
                       cutup_img_size=250,sigma=5,smoothing=False,smooth_param=5,
                       new_algorithm=True,pbcorr_path=PATH_Cosmo_r0p0_corfac,pbcorr=True,
                       pbimage=False,pboperation='multiply',remove_1pixel=True)
# Out:
#
# ###########################
#  _____   ___    ___    ___
# |_   _| | _ \  / __|  | __|
#   | |   |   /  \__ \  | _|
#   |_|   |_|_\  |___/  |_|
#
# ###########################
# Topological Radio Source Finder.
#
# -------------------
# Starting TRSF
# NOTICE: Image path: /Users/rs17612/Documents/Radio_Data/MIGHTEE/MIGHTEE_Continuum_Early_Science_COSMOS_r0p0.app.restored.circ.fits
# Attempting to open Image...
# NOTICE: Input Image Size (5450, 5450)
# NOTICE: Image Size with reduced padding (4703, 4703)
# Attempting to open PB Image...
# Error ValueError: data is not 3D!!
# Error ValueError: data is not 3D!!
# NOTICE: Input Image Size (5450, 5450)
# NOTICE: Image Size with reduced padding (4703, 4703)
# NOTICE: Image being pbcorrected.
# NOTICE: Image being multiplied by pbcorrection image.
# NOTICE: Image being multiplied by pbcorrection image.
# Calculating persistence diagrams and source properties..
# Cutouts Completed:   0%|          | 0/361 [00:00<?, ?it/s]
# Calculating properties...
#       Birth     Death     x1     y1   x2   y2  lifetime        dist  \
# 0  0.000092  0.000044  174.0  236.0  0.0  0.0  0.000047  293.209822
#
#   enclosed_i  new_row  parent_tag  single
# 0         []        0         NaN       0
# 7.818182119809085 7.818182119809085 0.0
# 0.003584042780857999
# [[0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 4.02746106e-83
#   1.84178105e-83 7.88903865e-84]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 3.20379580e-85
#   1.46511420e-85 6.27563334e-86]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 2.38713917e-87
#   1.09165244e-87 4.67595661e-88]]
# Cutouts Completed:   1%|▏         | 5/361 [00:00<00:30, 11.80it/s]
# beam*mask sum:  0.003821970335790064
# sum beam:  0.00878898790480179
# correction factor:  2.299596054553093
# mask*img sum: 0.003584042780857999
# Beam 69.25896321379291
# Flux_density:  5.1748432470676044e-05
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Cosmo_r0p0_data = trsf(PATH_Cosmo_r0p0,gaussian_fitting=True,region_expansion=False,
#       2                        cutup_img_size=250,sigma=5,smoothing=False,smooth_param=5,
#       3                        new_algorithm=True,pbcorr_path=PATH_Cosmo_r0p0_corfac,pbcorr=True,
#       4                        pbimage=False,pboperation='multiply',remove_1pixel=True)
#
# File ~/Documents/GitHub/TRSF/TRSF/main.py:87, in trsf.__init__(self, img_path, cutup_img_size, method, gaussian_fitting, region_expansion, cutup_img, sigma, plot, expsigma, smoothing, smooth_param, arrtype, arr, lifetime_limit, remove_1pixel, new_algorithm, pbcorr_path, pbcorr, pbimage, pboperation)
#      85 self.correctionf_list = None
#      86 #add here where it reads and prints image basic info.
# ---> 87 self._main()
#
# File ~/Documents/GitHub/TRSF/TRSF/main.py:182, in trsf._main(self)
#     179 if len(pd) == 0:
#     180     continue
# --> 182 src_cat = self._create_component_catalogue(pd,img,local_bg,sigma,self.Cutoutspb[num])
#     183 # alter catalogue to include the cutout coordinates
#     184 src_cat['Yc'] = src_cat['x_c'] + self.Coords[num][0]
#
# File ~/Documents/GitHub/TRSF/TRSF/main.py:398, in trsf._create_component_catalogue(self, pd, img, local_bg, sigma, pbimg)
#     396 def _create_component_catalogue(self,pd,img,local_bg,sigma,pbimg):
#     397     props = cp.cal_props(pd,img,local_bg,sigma,pbimg=pbimg,method=self.method,expsigma=self.expsigma,beam=self.Beam,bmajp=self.BMAJp,bminp=self.BMINp,bpa=self.BPA)
# --> 398     source_catalogue, correctionf_list = props.fit_all_single_sources(gaussian_fit=self.gaussian_fitting,expand=self.region_expansion)
#     399     if self.correctionf_list == None:
#     400         self.correctionf_list = correctionf_list
#
# TypeError: cannot unpack non-iterable NoneType object
